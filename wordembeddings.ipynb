# %%
# import keras

# %%
'''This script loads pre-trained word embeddings (GloVe embeddings)
into a frozen Keras Embedding layer, and uses it to
train a text classification model on the 20 Newsgroup dataset
(classication of newsgroup messages into 20 different categories).
GloVe embedding data can be found at:
http://nlp.stanford.edu/data/glove.6B.zip
(source page: http://nlp.stanford.edu/projects/glove/)
20 Newsgroup data can be found at:
http://www.cs.cmu.edu/afs/cs.cmu.edu/project/theo-20/www/data/news20.html
'''

from __future__ import print_function
import os
import numpy as np
np.random.seed(1337)

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.layers import Dense, Input, Flatten
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model
import sys
from keras.layers.recurrent import LSTM
# keras.layers.recurrent.Recurrent(weights=None, return_sequences=False, go_backwards=False, stateful=False, unroll=False, consume_less='cpu', input_dim=None, input_length=None)


BASE_DIR = ''
GLOVE_DIR = ''
TEXT_DATA_DIR = '/home/i008/20_newsgroup'
MAX_SEQUENCE_LENGTH = 1000
MAX_NB_WORDS = 20000
EMBEDDING_DIM = 100
VALIDATION_SPLIT = 0.2

# first, build index mapping words in the embeddings set
# to their embedding vector

print('Indexing word vectors.')

embeddings_index = {}
f = open(os.path.join(GLOVE_DIR, 'glove.6B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

# second, prepare text samples and their labels
print('Processing text dataset')

texts = []  # list of text samples
labels_index = {}  # dictionary mapping label name to numeric id
labels = []  # list of label ids
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[name] = label_id
        for fname in sorted(os.listdir(path)):
            if fname.isdigit():
                fpath = os.path.join(path, fname)
                if sys.version_info < (3,):
                    f = open(fpath)
                else:
                    f = open(fpath, encoding='latin-1')
                texts.append(f.read())
                f.close()
                labels.append(label_id)

# print('Found %s texts.' % len(texts))
# # finally, vectorize the text samples into a 2D integer tensor
# tokenizer = Tokenizer(nb_words=MAX_NB_WORDS)
# tokenizer.fit_on_texts(texts)
# sequences = tokenizer.texts_to_sequences(texts)

# word_index = tokenizer.word_index
# print('Found %s unique tokens.' % len(word_index))

# data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

# labels = to_categorical(np.asarray(labels))
# print('Shape of data tensor:', data.shape)
# print('Shape of label tensor:', labels.shape)

# # split the data into a training set and a validation set
# indices = np.arange(data.shape[0])
# np.random.shuffle(indices)
# data = data[indices]
# labels = labels[indices]
# nb_validation_samples = int(VALIDATION_SPLIT * data.shape[0])

# x_train = data[:-nb_validation_samples]
# y_train = labels[:-nb_validation_samples]
# x_val = data[-nb_validation_samples:]
# y_val = labels[-nb_validation_samples:]

# print('Preparing embedding matrix.')

# # prepare embedding matrix
# nb_words = min(MAX_NB_WORDS, len(word_index))
# embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
# for word, i in word_index.items():
#     if i >= MAX_NB_WORDS:
#         continue
#     embedding_vector = embeddings_index.get(word)
#     if embedding_vector is not None:
#         # words not found in embedding index will be all-zeros.
#         embedding_matrix[i] = embedding_vector

# # load pre-trained word embeddings into an Embedding layer
# # note that we set trainable = False so as to keep the embeddings fixed
# embedding_layer = Embedding(nb_words,
#                             EMBEDDING_DIM,
#                             weights=[embedding_matrix],
#                             input_length=MAX_SEQUENCE_LENGTH,
#                             trainable=False)

# print('Training model.')
# Out:
# Indexing word vectors.
# Found 400000 word vectors.
# Processing text dataset

# %%
np.unique(np.asarray(labels)).shape

to_categorical(labels).shape
# Out:
# (19997, 20)

# %%
# train a 1D convnet with global maxpooling
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
# x = Conv1D(128, 5, activation='relu')(embedded_sequences)
x = LSTM(1000, dropout_W=0.2, dropout_U=0.2)(embedded_sequences) # try using a GRU instead, for fun
# x = LSTM(100, dropout_W=0.2, dropout_U=0.2)(x) # try using a GRU instead, for fun
# x = LSTM(128, dropout_W=0.2, dropout_U=0.2)(x) # try using a GRU instead, for fun

# x = MaxPooling1D(5)(x)
# x = Conv1D(128, 5, activation='relu')(x)
# x = MaxPooling1D(5)(x)
# x = Conv1D(128, 5, activation='relu')(x)
# x = MaxPooling1D(35)(x)
x = Dense(128, activation='relu')(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['acc'])

# happy learning!
model.fit(x_train, y_train, validation_data=(x_val, y_val),
          nb_epoch=2, batch_size=128)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-14-ef9698171f8a> in <module>()
#      14 # x = MaxPooling1D(35)(x)
#      15 x = Dense(128, activation='relu')(x)
# ---> 16 x = Flatten()(x)
#      17 x = Dense(128, activation='relu')(x)
#      18 preds = Dense(len(labels_index), activation='softmax')(x)
#
# /home/i008/anaconda2/lib/python2.7/site-packages/keras/engine/topology.pyc in __call__(self, x, mask)
#     472             # Raise exceptions in case the input is not compatible
#     473             # with the input_spec specified in the layer constructor.
# --> 474             self.assert_input_compatibility(x)
#     475
#     476             # Collect input shapes to build layer.
#
# /home/i008/anaconda2/lib/python2.7/site-packages/keras/engine/topology.pyc in assert_input_compatibility(self, input)
#     406                                         self.name + ': expected ndim >= ' +
#     407                                         str(ndim) + ', found ndim=' +
# --> 408                                         str(K.ndim(x)))
#     409                 else:
#     410                     if K.ndim(x) != spec.ndim:
#
# Exception: Input 0 is incompatible with layer flatten_6: expected ndim >= 3, found ndim=2

# %%
# LSTM and CNN for sequence classification in the IMDB dataset
import numpy
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.convolutional import Convolution1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
model = Sequential()

model.add(Embedding(input_dim=nb_words, 
                    output_dim=EMBEDDING_DIM, 
                    input_length=MAX_SEQUENCE_LENGTH, 
                    weights=[embedding_matrix], 
                    trainable=True)
         )
model.add(Convolution1D(nb_filter=32, filter_length=3, border_mode='same', activation='relu'))
model.add(MaxPooling1D(pool_length=2))
model.add(LSTM(100))
model.add(Dense(len(labels_index), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
print(model.summary())
model.fit(x_train, y_train, nb_epoch=3, batch_size=128, validation_data=(x_val, y_val))
# Final evaluation of the model
# scores = model.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# embedding_5 (Embedding)          (None, 1000, 100)     2000000     embedding_input_4[0][0]
# ____________________________________________________________________________________________________
# convolution1d_2 (Convolution1D)  (None, 1000, 32)      9632        embedding_5[0][0]
# ____________________________________________________________________________________________________
# maxpooling1d_2 (MaxPooling1D)    (None, 500, 32)       0           convolution1d_2[0][0]
# ____________________________________________________________________________________________________
# lstm_4 (LSTM)                    (None, 100)           53200       maxpooling1d_2[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 20)            2020        lstm_4[0][0]
# ====================================================================================================
# Total params: 2064852
# ____________________________________________________________________________________________________
# None
# Train on 15998 samples, validate on 3999 samples
# Epoch 1/3
# 15998/15998 [==============================] - 55s - loss: 2.5677 - acc: 0.1684 - val_loss: 2.2266 - val_acc: 0.2188
# Epoch 2/3
# 15998/15998 [==============================] - 55s - loss: 2.0898 - acc: 0.2771 - val_loss: 2.1155 - val_acc: 0.2846
# Epoch 3/3
# 15998/15998 [==============================] - 55s - loss: 1.9088 - acc: 0.3262 - val_loss: 1.8085 - val_acc: 0.3323
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-86a311db5eb6> in <module>()
#      19 model.fit(x_train, y_train, nb_epoch=3, batch_size=128, validation_data=(x_val, y_val))
#      20 # Final evaluation of the model
# ---> 21 scores = model.evaluate(x_test, y_test, verbose=0)
#      22 print("Accuracy: %.2f%%" % (scores[1]*100))
#
# NameError: name 'x_test' is not defined

# %%
t = Tokenizer(nb_words=10)

# %%
t.fit_on_texts(texts)

# %%
len(t.texts_to_sequences([texts[10]])[0])
# Out:
# 32

# %%
len(t.texts_to_sequences([texts[10]])[0])
# Out:
# 32

# %%
sorted(t.word_index, key=lambda x: )
# Out:
# ['\x02',
#  '\x02ubject',
#  '\x03',
#  '\x03\x03\x1b',
#  '\x08',
#  '\x08a',
#  '\x08b',
#  '\x08c',
#  '\x08d',
#  '\x08e',
#  '\x08f',
#  '\x08h',
#  '\x08i',
#  '\x08k',
#  '\x08l',
#  '\x08m',
#  '\x08n',
#  '\x08o',
#  '\x08p',
#  '\x08r',
#  '\x08s',
#  '\x08t',
#  '\x08u',
#  '\x08v',
#  '\x08w',
#  '\x08y',
#  '\x0c',
#  '\r',
#  '\r\r',
#  '\remail',
#  '\reven',
#  '\rfax',
#  '\rin',
#  '\x10a',
#  '\x10more',
#  '\x10where',
#  '\x18',
#  '\x18\xe93\xdaj\xdd\x08\x05',
#  '\x19',
#  '\x1a',
#  '\x1b',
#  '\x1c',
#  '\x1e\x1e\x1e\x1e\x1e\x1e\x1e\x1e\x1e\x1e\x1e',
#  "'",
#  "''",
#  "'''",
#  "'''''",
#  "''0y",
#  "''1",
#  "''3",
#  "''4",
#  "''5",
#  "''5y'",
#  "''83",
#  "''8y",
#  "''9",
#  "''9265e965e9",
#  "''a",
#  "''a6t",
#  "''after",
#  "''ahmadya",
#  "''america's",
#  "''aq",
#  "''b9",
#  "''bar'",
#  "''bpu",
#  "''c",
#  "''c4",
#  "''c7'os6",
#  "''close",
#  "''d",
#  "''dk",
#  "''dz",
#  "''e5f",
#  "''first",
#  "''i",
#  "''ipx",
#  "''j",
#  "''ji'",
#  "''k",
#  "''kbl",
#  "''l",
#  "''m",
#  "''my",
#  "''n",
#  "''or'",
#  "''our",
#  "''patterns",
#  "''pv6rx",
#  "''q",
#  "''qs0p",
#  "''s",
#  "''sir",
#  "''somethings''",
#  "''t",
#  "''the",
#  "''they",
#  "''turks",
#  "''weird''",
#  "''woe",
#  "'0",
#  "'0'",
#  "'000'",
#  "'012c",
#  "'030",
#  "'03f",
#  "'04",
#  "'040",
#  "'04wsedwjy",
#  "'05",
#  "'0825",
#  "'0877",
#  "'08x",
#  "'08xt",
#  "'09",
#  "'098",
#  "'0a",
#  "'0b",
#  "'0dbeav",
#  "'0e3gf",
#  "'0erdivbud",
#  "'0f",
#  "'0f2",
#  "'0hd",
#  "'0j",
#  "'0l",
#  "'0l'etl77t",
#  "'0l38",
#  "'0lnbq",
#  "'0lowt",
#  "'0mi",
#  "'0n",
#  "'0nu",
#  "'0omdcua8a4",
#  "'0p",
#  "'0r",
#  "'0u",
#  "'0u'c4l",
#  "'0v9g",
#  "'0wd",
#  "'0xhi",
#  "'0y",
#  "'0yhk",
#  "'1",
#  "'1'",
#  "'10",
#  "'10'",
#  "'1000",
#  "'11",
#  "'113p",
#  "'113q",
#  "'113r6",
#  "'113r61",
#  "'113s",
#  "'113s1",
#  "'113s1t3s",
#  "'113s1t45",
#  "'113s1w",
#  "'1144",
#  "'1145w",
#  "'1147",
#  "'117",
#  "'12'",
#  "'1285",
#  "'14",
#  "'15",
#  "'1984'",
#  "'1a",
#  "'1a04a",
#  "'1a7",
#  "'1c6r",
#  "'1ck6",
#  "'1cm",
#  "'1d",
#  "'1e",
#  "'1ecqs",
#  "'1ecqst3p",
#  "'1ecr6t",
#  "'1ecs1t3p",
#  "'1ed66w",
#  "'1em",
#  "'1g9",
#  "'1gca",
#  "'1gjp1m",
#  "'1h",
#  "'1h870",
#  "'1h92",
#  "'1hg7",
#  "'1hh3n",
#  "'1i'0o",
#  "'1inrl",
#  "'1k0z3w",
#  "'1kbxey",
#  "'1l",
#  "'1m",
#  "'1n",
#  "'1p",
#  "'1pmfq",
#  "'1r",
#  "'1r9",
#  "'1r96ue",
#  "'1s",
#  "'1sbhpp7",
#  "'1t",
#  "'1t'c4u'gtu",
#  "'1t3p",
#  "'1t3q",
#  "'1t3qs",
#  "'1t44",
#  "'1t47",
#  "'1t471",
#  "'1t47117",
#  "'1t7",
#  "'1t99",
#  "'1t99s",
#  "'1tdo25",
#  "'1te",
#  "'1te145",
#  "'1tnah",
#  "'1tpazz",
#  "'1tpjw49",
#  "'1u",
#  "'1uhl7y",
#  "'1v",
#  "'1vj9u",
#  "'1w",
#  "'1w3p",
#  "'1w3q",
#  "'1w44",
#  "'1w45",
#  "'1w45s17",
#  "'1w45w",
#  "'1w45ww",
#  "'1w47",
#  "'1w7",
#  "'1w86",
#  "'1w87",
#  "'1wl",
#  "'1xj",
#  "'1xxo",
#  "'1y",
#  "'1yuo",
#  "'1z",
#  "'1z4",
#  "'1z5'1t",
#  "'1z5'1z6e",
#  "'1z5'i",
#  "'1z5k",
#  "'1z6e",
#  "'1z6e1t",
#  "'1z6ei",
#  "'1z6ei0l",
#  "'1z6ei0m75",
#  "'1z6ei0mfq",
#  "'1z6ei0o",
#  "'1z6ei4",
#  "'2",
#  "'2'",
#  "'20",
#  "'20's",
#  "'20s",
#  "'21",
#  "'22",
#  "'23",
#  "'24",
#  "'245",
#  "'24e",
#  "'24e1",
#  "'24e145",
#  "'24e1484g",
#  "'24e1486",
#  "'24eq486",
#  "'24g",
#  "'25",
#  "'25w",
#  "'26",
#  "'26cl",
#  "'27",
#  "'27fur",
#  "'286",
#  "'2a",
#  "'2a2",
#  "'2a3",
#  "'2fk",
#  "'2h",
#  "'2lp",
#  "'2m",
#  "'2ofbm",
#  "'2p",
#  "'2pi",
#  "'2purcw'",
#  "'2pzu",
#  "'2rlb",
#  "'2rlgw",
#  "'2tj",
#  "'2tm",
#  "'2uu",
#  "'2v",
#  "'2w1",
#  "'2y",
#  "'2z",
#  "'2z'ay",
#  "'2z'et'86",
#  "'2z'gvznkhf7",
#  "'2z77u",
#  "'2znay",
#  "'2znbp",
#  "'3",
#  "'3'",
#  "'3'4",
#  "'30's",
#  "'30z",
#  "'31",
#  "'31c",
#  "'32",
#  "'32m",
#  "'34",
#  "'34t2p",
#  "'35",
#  "'36",
#  "'386",
#  "'386sl",
#  "'39",
#  "'39r7",
#  "'3b",
#  "'3hb",
#  "'3i",
#  "'3k",
#  "'3n",
#  "'3n78a1q",
#  "'3nl",
#  "'3o",
#  "'3o6fpd",
#  "'3pmqf",
#  "'3q",
#  "'3riz",
#  "'3s",
#  "'3u",
#  "'3v",
#  "'3x2g0c",
#  "'3x7",
#  "'3y",
#  "'3yu",
#  "'4",
#  "'4'",
#  "'4'a",
#  "'40s",
#  "'42",
#  "'43",
#  "'442",
#  "'451rq",
#  "'47",
#  "'48",
#  "'486dx2",
#  "'486dx2sx'",
#  "'49j",
#  "'49w",
#  "'4ac",
#  "'4ad",
#  "'4b",
#  "'4bh",
#  "'4e",
#  "'4ed",
#  "'4efi",
#  "'4eq",
#  "'4h8vwehz",
#  "'4i",
#  "'4i3'4rj74",
#  "'4jk",
#  "'4jms",
#  "'4jsy",
#  "'4jtj",
#  "'4n",
#  "'4ntg",
#  "'4o",
#  "'4ok",
#  "'4p",
#  "'4q",
#  "'4u",
#  "'4w",
#  "'4x",
#  "'4yj",
#  "'5",
#  "'5'",
#  "'5'1t",
#  "'5'v5x",
#  "'50",
#  "'50's",
#  "'50s",
#  "'51",
#  "'52",
#  "'523n41'",
#  "'524p1ra03",
#  "'53",
#  "'532",
#  "'53ott",
#  "'53qs5w",
#  "'54",
#  "'55xm6",
#  "'56",
#  "'57",
#  "'573",
#  "'58",
#  "'5a",
#  "'5czb",
#  "'5d960",
#  "'5dwlst",
#  "'5g",
#  "'5j",
#  "'5jfal",
#  "'5jfp",
#  "'5k",
#  "'5m",
#  "'5n",
#  "'5n86qt97",
#  "'5nfj2w1",
#  "'5nw32",
#  "'5o",
#  "'5of",
#  "'5s",
#  "'5s92",
#  "'5s961",
#  "'5t",
#  "'5tr",
#  "'5u",
#  "'5ug",
#  "'5ugg",
#  "'5ugix",
#  "'5ugiz",
#  "'5ugiz54g9v4i4s",
#  "'5uj",
#  "'5uj75u",
#  "'5uj9z",
#  "'5up",
#  "'5w",
#  "'5ws",
#  "'5x",
#  "'5y",
#  "'5z",
#  "'5zxe'",
#  "'6",
#  "'6'",
#  "'6'ax",
#  "'60",
#  "'60's",
#  "'60p",
#  "'60s",
#  "'61",
#  "'611x18",
#  "'61mb7",
#  "'62",
#  "'63",
#  "'63dy",
#  "'63s",
#  "'64",
#  "'65",
#  "'65d'v",
#  "'65ds",
#  "'65e9",
#  "'65e94g9v4cdy",
#  "'65e965e9",
#  "'65e965e9e952",
#  "'65e9e5",
#  "'65f5",
#  "'65hp",
#  "'66",
#  "'66o",
#  "'67",
#  "'67axev6",
#  "'67nv",
#  "'68",
#  "'69",
#  "'6952",
#  "'69524e",
#  "'69524g9v",
#  "'6b6",
#  "'6bq",
#  "'6bu'8",
#  "'6c",
#  "'6ch",
#  "'6cj2d",
#  "'6cjp",
#  "'6cjz",
#  "'6cl",
#  "'6cp88gn4v1vs",
#  "'6d6",
#  "'6e",
#  "'6g",
#  "'6g'qy''",
#  "'6ht9p",
#  "'6i",
#  "'6igi",
#  "'6j",
#  "'6j2m0x23t7",
#  "'6j3",
#  "'6l",
#  "'6nsuiwuuo",
#  "'6obf",
#  "'6q",
#  "'6q04",
#  "'6qz'",
#  "'6s8x876i",
#  "'6se",
#  "'6ul4",
#  "'6um",
#  "'6v75c",
#  "'6vm8f",
#  "'6xcv",
#  "'6zh4r",
#  "'6zh4u",
#  "'6zhx876",
#  "'6zi",
#  "'6zi7u",
#  "'6zjbu",
#  "'7",
#  "'70",
#  "'70's",
#  "'70s",
#  "'71",
#  "'72",
#  "'72105",
#  "'73",
#  "'74",
#  "'75",
#  "'753",
#  "'76",
#  "'77",
#  "'78",
#  "'79",
#  "'7b0",
#  "'7c3isq8",
#  "'7dy",
#  "'7gpl",
#  "'7h",
#  "'7h3",
#  "'7hp",
#  "'7j8",
#  "'7m0t5",
#  "'7o",
#  "'7p",
#  "'7r7kf",
#  "'7rts",
#  "'7s",
#  "'7t",
#  "'7u",
#  "'7w7",
#  "'7y",
#  "'7z",
#  "'7z50",
#  "'7z6qo",
#  "'7zttp",
#  "'8",
#  "'8'",
#  "'80",
#  "'80's",
#  "'80s",
#  "'81",
#  "'816",
#  "'82",
#  "'827519y",
#  "'82lk",
#  "'83",
#  "'83a",
#  "'84",
#  "'85",
#  "'86",
#  "'863",
#  "'86xr0zv",
#  "'87",
#  "'87oyo3",
#  "'88",
#  "'88cbr1000",
#  "'88fk",
#  "'89",
#  "'89cbr600",
#  "'89kx250",
#  "'89s",
#  "'8ah",
#  "'8b4",
#  "'8bn",
#  "'8c",
#  "'8d3k4u",
#  "'8d88zrb",
#  "'8d8fajx",
#  "'8f",
#  "'8h'3auv",
#  "'8if",
#  "'8j",
#  "'8j1sn",
#  "'8js0dgf5",
#  "'8m807",
#  "'8mib1l",
#  "'8n",
#  "'8n1",
#  "'8n8",
#  "'8nj",
#  "'8oyq",
#  "'8q",
#  "'8r",
#  "'8rck",
#  "'8ri",
#  "'8rm",
#  "'8rs",
#  "'8sivy6",
#  "'8tr",
#  "'8u",
#  "'8uz",
#  "'8v",
#  "'8y438",
#  "'8zl3",
#  "'9",
#  "'9'",
#  "'90",
#  "'90p8001m",
#  "'90s",
#  "'90vanagon",
#  "'91",
#  "'91'",
#  "'91s",
#  "'92",
#  "'92'",
#  "'924a",
#  "'92k75s",
#  "'92s",
#  "'93",
#  "'93b6",
#  "'93m'b",
#  "'94",
#  "'94s",
#  "'95",
#  "'96",
#  "'96u",
#  "'989lb",
#  "'9a1",
#  "'9b",
#  "'9c",
#  "'9d",
#  "'9d0",
#  "'9e",
#  "'9g",
#  "'9h",
#  "'9hy46",
#  "'9i",
#  "'9j7",
#  "'9l",
#  "'9m",
#  "'9netldle",
#  "'9netm",
#  "'9o",
#  "'9oal",
#  "'9p",
#  "'9q",
#  "'9qm60u",
#  "'9s",
#  "'9suo",
#  "'9t",
#  "'9tea",
#  "'9v",
#  "'9x",
#  "'9zqv",
#  "'a",
#  "'a'",
#  "'a'8",
#  "'a0",
#  "'a00l",
#  "'a0n7",
#  "'a1vt",
#  "'a2",
#  "'a2a'b'ax",
#  "'a4",
#  "'a5",
#  "'a70ss63iqx5",
#  "'a9",
#  "'aa",
#  "'aa2g9",
#  "'ab",
#  "'ability'",
#  "'abject",
#  "'abnormal",
#  "'abnormal'",
#  "'about",
#  "'absolutely'",
#  "'ac5iq",
#  "'ac7'",
#  "'access",
#  "'according",
#  "'accuracy'",
#  "'accurate'",
#  "'accurately",
#  "'acquaintances'",
#  "'action'",
#  "'actual",
#  "'ad",
#  "'adjustment'",
#  "'adobe",
#  "'adp0000",
#  "'advanced",
#  "'advanced'",
#  "'aes",
#  "'afdoq",
#  "'afdu",
#  "'afdzqvg'al",
#  "'afei",
#  "'afeial",
#  "'afeid6g'",
#  "'afeid8",
#  "'afeiqy''d",
#  "'aff1",
#  "'aff1o",
#  "'afg'",
#  "'afg'ovduq",
#  "'afg'q",
#  "'afg'qr",
#  "'afg'qvdzqy''",
#  "'african",
#  "'after",
#  "'agent",
#  "'aggressive'",
#  "'agnosticism'",
#  "'agricultural'",
#  "'ah",
#  "'ah8ual",
#  "'ah9iac6",
#  "'ai",
#  "'ai''",
#  "'ai''d",
#  "'ai''q",
#  "'ai''qsii",
#  "'aib",
#  "'ak",
#  "'al",
#  "'alarmist'",
#  "'algemeen",
#  "'all",
#  "'all'",
#  "'allegorically'",
#  "'allowed'",
#  "'allows'",
#  "'almost",
#  "'alone'",
#  "'alt",
#  "'alt'",
#  "'alterna",
#  "'alternative'",
#  "'alway",
#  "'always",
#  "'am",
#  "'ame",
#  "'americans'",
#  "'amplitudes'",
#  "'anal",
#  "'and",
#  "'and'",
#  "'anecdote'",
#  "'annual",
#  "'anode'",
#  "'anon'",
#  "'anonymous",
#  "'anonymous'",
#  "'another",
#  "'ansiccoptions",
#  "'anti",
#  "'any",
#  "'ao",
#  "'ap",
#  "'ap'k",
#  "'ap'kgb",
#  "'api8",
#  "'apocrypha'",
#  "'apologists'",
#  "'appears'",
#  "'apply'",
#  "'approved'",
#  "'april",
#  "'aq",
#  "'aq04",
#  "'aq046um",
#  "'aq0n",
#  "'aq0n5smdt",
#  "'aq0n5t",
#  "'aq1",
#  "'aq17",
#  "'aq175u",
#  "'aq17su",
#  "'aq17ze",
#  "'aq3",
#  "'aqp",
#  "'aqph4",
#  "'aqr",
#  "'aquanauts'",
#  "'ar",
#  "'ar'",
#  "'ar4e",
#  "'ara2",
#  "'arab'",
#  "'aramaniya'",
#  "'ararat'",
#  "'aravy",
#  "'archie'",
#  "'archive",
#  "'are",
#  "'are'",
#  "'armen'",
#  "'armenia'",
#  "'armenian",
#  "'armenian'",
#  "'armenians",
#  "'armenie'",
#  "'armenien",
#  "'armeniya'",
#  "'armin'",
#  "'armina'",
#  "'arming",
#  "'arminia'",
#  "'arminik'",
#  "'arms'",
#  "'arn",
#  "'arrest'",
#  "'arresting'",
#  "'arrogance",
#  "'arromdian",
#  "'arromdian'",
#  "'arromdians'",
#  "'articles'",
#  "'aryans'",
#  "'as",
#  "'as'",
#  "'asa",
#  "'asala",
#  "'asau",
#  "'asb",
#  "'asc",
#  "'asf",
#  "'asjw",
#  "'asn",
#  "'assault",
#  "'assimilation",
#  "'association",
#  "'astral",
#  "'astrology'",
#  "'asus'",
#  "'asx",
#  "'at",
#  "'at0z",
#  "'at8w",
#  "'ataturk",
#  "'athens",
#  "'atm",
#  "'ato",
#  "'au",
#  "'au4e1",
#  "'au791",
#  "'au792ns4",
#  "'au79vuh",
#  "'aud",
#  "'aufij75u6q2bsu",
#  "'aug",
#  "'aug9",
#  "'aul",
#  "'aul4",
#  "'aul45",
#  "'aul45u",
#  "'aul4su",
#  "'auln",
#  "'auln5t",
#  "'aulx",
#  "'aum",
#  "'aum75",
#  "'aum7su",
#  "'aun",
#  "'aunbsu",
#  "'auo",
#  "'auo35r'q81big",
#  "'austron'",
#  "'authentic",
#  "'authority'",
#  "'authorized",
#  "'auto",
#  "'auto'biography",
#  "'autocar",
#  "'automated'",
#  "'autoplacewindows'",
#  "'av",
#  "'av'6",
#  "'av8",
#  "'average",
#  "'average'",
#  "'avm",
#  "'avmk",
#  "'avn",
#  "'avp",
#  "'avp2",
#  "'avpv2np",
#  "'avpv2ns",
#  "'avpv2o",
#  "'avpv7",
#  "'avpv7qw",
#  "'avpvt",
#  "'avpvv",
#  "'avql",
#  "'avqn2ns",
#  "'avqnt",
#  "'avs",
#  "'avs41",
#  "'avs9v",
#  "'avy",
#  "'avyaa",
#  "'aw",
#  "'aw4",
#  "'aw4e",
#  "'aw4ep",
#  "'aw4x",
#  "'aw5",
#  "'aw5a",
#  "'aw5e",
#  "'aw5u",
#  "'aw5u6um",
#  "'aw5ugiyxg",
#  "'aw5uj9z",
#  "'aw6",
#  "'aw6igiyx",
#  "'aw6igiyxg",
#  "'aw6igiz",
#  "'aw7",
#  "'aw70",
#  "'aw76",
#  "'aw79v0",
#  "'aw83",
#  "'aw83o",
#  "'aw9v",
#  "'aware'",
#  "'awb",
#  "'awc",
#  "'ax",
#  "'ax'6ub0d",
#  "'ax03a",
#  "'ax12",
#  "'ax1a",
#  "'ax1u",
#  "'ax2",
#  "'ax2agn't",
#  "'ax2k",
#  "'ax65p2",
#  "'ax6k",
#  "'ax7",
#  "'ax8'6um",
#  "'axer'",
#  "'axgg",
#  "'axgiz",
#  "'axl",
#  "'axle'",
#  "'axu",
#  "'ay",
#  "'ay4",
#  "'ay52a",
#  "'ay654",
#  "'ayt",
#  "'ayt'bqt735",
#  "'ayya",
#  "'ayyup",
#  "'ayyx",
#  "'ayz",
#  "'ayzi",
#  "'az",
#  "'az'dy",
#  "'azdx6q17z",
#  "'azea",
#  "'azf",
#  "'azfbs",
#  "'azg0",
#  "'azg6",
#  "'azg6t",
#  "'azjj6vy",
#  "'azjjp",
#  "'azz",
#  "'azz'kh",
#  "'b",
#  "'b'",
#  "'b1",
#  "'b447",
#  "'b44np",
#  "'b7",
#  "'b9mddc70f",
#  "'baby",
#  "'back",
#  "'backdoor'",
#  "'bad",
#  "'bad'",
#  "'bait'",
#  "'baits'",
#  "'ban'",
#  "'bang'",
#  "'banging'",
#  "'banks'",
#  "'banned'",
#  "'barbarism'",
#  "'basebrawl'",
#  "'batch",
#  "'be",
#  "'be0",
#  ...]

# %%
for w,i in t.word_index.items():  
    print(w)
    print(i)
    if i > 100:
        break
# Out:
# 9304191946
# 108721

# %%
import operator

sorted_x = sorted(word_index.items(), key=operator.itemgetter(1))

# %%
sorted_x
# Out:
# [('the', 1),
#  ('edu', 2),
#  ('to', 3),
#  ('of', 4),
#  ('a', 5),
#  ('and', 6),
#  ('in', 7),
#  ('i', 8),
#  ('is', 9),
#  ('that', 10),
#  ("'ax", 11),
#  ('cmu', 12),
#  ('it', 13),
#  ('for', 14),
#  ('com', 15),
#  ('cs', 16),
#  ('you', 17),
#  ('from', 18),
#  ('on', 19),
#  ('this', 20),
#  ('news', 21),
#  ('not', 22),
#  ('be', 23),
#  ('srv', 24),
#  ('are', 25),
#  ('have', 26),
#  ('with', 27),
#  ('as', 28),
#  ('cantaloupe', 29),
#  ('1', 30),
#  ('or', 31),
#  ('net', 32),
#  ('was', 33),
#  ('if', 34),
#  ('but', 35),
#  ('message', 36),
#  ('they', 37),
#  ('subject', 38),
#  ('lines', 39),
#  ('date', 40),
#  ('id', 41),
#  ('apr', 42),
#  ('newsgroups', 43),
#  ('path', 44),
#  ('organization', 45),
#  ('at', 46),
#  ('by', 47),
#  ('state', 48),
#  ('gmt', 49),
#  ('an', 50),
#  ('can', 51),
#  ('2', 52),
#  ('my', 53),
#  ('what', 54),
#  ('1993', 55),
#  ('all', 56),
#  ('would', 57),
#  ('ohio', 58),
#  ('x', 59),
#  ('there', 60),
#  ('one', 61),
#  ('will', 62),
#  ('do', 63),
#  ('re', 64),
#  ('0', 65),
#  ('writes', 66),
#  ('about', 67),
#  ('3', 68),
#  ('we', 69),
#  ('no', 70),
#  ('so', 71),
#  ('article', 72),
#  ('your', 73),
#  ('comp', 74),
#  ('has', 75),
#  ('he', 76),
#  ('references', 77),
#  ('m', 78),
#  ('talk', 79),
#  ('any', 80),
#  ('me', 81),
#  ('misc', 82),
#  ('some', 83),
#  ('who', 84),
#  ('ca', 85),
#  ('ans', 86),
#  ('sender', 87),
#  ('out', 88),
#  ('howland', 89),
#  ('which', 90),
#  ('reston', 91),
#  ("'", 92),
#  ('like', 93),
#  ('more', 94),
#  ("don't", 95),
#  ('people', 96),
#  ('when', 97),
#  ('just', 98),
#  ('university', 99),
#  ('were', 100),
#  ('posting', 101),
#  ('their', 102),
#  ('4', 103),
#  ('5', 104),
#  ('nntp', 105),
#  ('up', 106),
#  ('cc', 107),
#  ('other', 108),
#  ('mps', 109),
#  ('know', 110),
#  ('how', 111),
#  ('host', 112),
#  ('93', 113),
#  ('sci', 114),
#  ('only', 115),
#  ('get', 116),
#  ('them', 117),
#  ('had', 118),
#  ('than', 119),
#  ('think', 120),
#  ('usenet', 121),
#  ('zaphod', 122),
#  ('may', 123),
#  ('6', 124),
#  ('been', 125),
#  ('his', 126),
#  ('alt', 127),
#  ('politics', 128),
#  ('s', 129),
#  ('c', 130),
#  ('windows', 131),
#  ('also', 132),
#  ('7', 133),
#  ('p', 134),
#  ('does', 135),
#  ('q', 136),
#  ('time', 137),
#  ('rutgers', 138),
#  ('20', 139),
#  ('then', 140),
#  ('r', 141),
#  ('use', 142),
#  ('harvard', 143),
#  ('eng', 144),
#  ('near', 145),
#  ('8', 146),
#  ('16', 147),
#  ('new', 148),
#  ('w', 149),
#  ("it's", 150),
#  ('e', 151),
#  ("i'm", 152),
#  ('these', 153),
#  ('rec', 154),
#  ('us', 155),
#  ('15', 156),
#  ('should', 157),
#  ('good', 158),
#  ('system', 159),
#  ('crabapple', 160),
#  ('sei', 161),
#  ('o', 162),
#  ('u', 163),
#  ('noc', 164),
#  ('well', 165),
#  ('soc', 166),
#  ('could', 167),
#  ('das', 168),
#  ('xref', 169),
#  ('d', 170),
#  ('g', 171),
#  ('because', 172),
#  ('now', 173),
#  ('am', 174),
#  ('cis', 175),
#  ('even', 176),
#  ('10', 177),
#  ('21', 178),
#  ('see', 179),
#  ('9', 180),
#  ('why', 181),
#  ('europa', 182),
#  ('very', 183),
#  ('gtefsd', 184),
#  ('ece', 185),
#  ('into', 186),
#  ('uunet', 187),
#  ('religion', 188),
#  ('way', 189),
#  ('those', 190),
#  ('b', 191),
#  ('org', 192),
#  ('world', 193),
#  ('uk', 194),
#  ('fs7', 195),
#  ('two', 196),
#  ('say', 197),
#  ('make', 198),
#  ('17', 199),
#  ('many', 200),
#  ('much', 201),
#  ('christian', 202),
#  ('first', 203),
#  ('gov', 204),
#  ('max', 205),
#  ('right', 206),
#  ('19', 207),
#  ('n', 208),
#  ('23', 209),
#  ('t', 210),
#  ('most', 211),
#  ('rochester', 212),
#  ('such', 213),
#  ('distribution', 214),
#  ('14', 215),
#  ('god', 216),
#  ('22', 217),
#  ('de', 218),
#  ('18', 219),
#  ('did', 220),
#  ('our', 221),
#  ('club', 222),
#  ('where', 223),
#  ('hp', 224),
#  ('space', 225),
#  ('after', 226),
#  ('mail', 227),
#  ('ac', 228),
#  ('00', 229),
#  ('andrew', 230),
#  ('want', 231),
#  ('gatech', 232),
#  ('magnesium', 233),
#  ('its', 234),
#  ('here', 235),
#  ('said', 236),
#  ('anyone', 237),
#  ('udel', 238),
#  ('v', 239),
#  ('reply', 240),
#  ('ibm', 241),
#  ('being', 242),
#  ('utexas', 243),
#  ('over', 244),
#  ('used', 245),
#  ('go', 246),
#  ('culture', 247),
#  ('sun', 248),
#  ('same', 249),
#  ('12', 250),
#  ('sys', 251),
#  ('need', 252),
#  ('l', 253),
#  ('h', 254),
#  ('uiuc', 255),
#  ('work', 256),
#  ('really', 257),
#  ('nasa', 258),
#  ('too', 259),
#  ('13', 260),
#  ('11', 261),
#  ('please', 262),
#  ('something', 263),
#  ('j', 264),
#  ('problem', 265),
#  ('computer', 266),
#  ('25', 267),
#  ('sura', 268),
#  ('believe', 269),
#  ('k', 270),
#  ('since', 271),
#  ('graphics', 272),
#  ('him', 273),
#  ('ms', 274),
#  ('hardware', 275),
#  ('still', 276),
#  ('back', 277),
#  ('z', 278),
#  ('off', 279),
#  ('24', 280),
#  ('netcom', 281),
#  ('mac', 282),
#  ('os', 283),
#  ('usa', 284),
#  ('years', 285),
#  ("i've", 286),
#  ('going', 287),
#  ('f', 288),
#  ('before', 289),
#  ('information', 290),
#  ('pc', 291),
#  ('help', 292),
#  ('find', 293),
#  ('point', 294),
#  ('take', 295),
#  ('government', 296),
#  ('might', 297),
#  ('better', 298),
#  ('file', 299),
#  ('using', 300),
#  ('question', 301),
#  ('never', 302),
#  ('last', 303),
#  ('30', 304),
#  ('things', 305),
#  ('year', 306),
#  ('both', 307),
#  ('read', 308),
#  ('own', 309),
#  ('while', 310),
#  ('thanks', 311),
#  ('au', 312),
#  ('software', 313),
#  ('must', 314),
#  ('mit', 315),
#  ("can't", 316),
#  ('david', 317),
#  ('etc', 318),
#  ('without', 319),
#  ('cso', 320),
#  ('sure', 321),
#  ('uucp', 322),
#  ('usc', 323),
#  ('made', 324),
#  ('another', 325),
#  ('26', 326),
#  ('number', 327),
#  ('access', 328),
#  ('data', 329),
#  ("doesn't", 330),
#  ('case', 331),
#  ('forsale', 332),
#  ('through', 333),
#  ('someone', 334),
#  ('look', 335),
#  ('got', 336),
#  ('cwru', 337),
#  ('between', 338),
#  ('thing', 339),
#  ('down', 340),
#  ('under', 341),
#  ('long', 342),
#  ('program', 343),
#  ('drive', 344),
#  ('bit', 345),
#  ('fact', 346),
#  ('part', 347),
#  ('available', 348),
#  ("that's", 349),
#  ('version', 350),
#  ('27', 351),
#  ('law', 352),
#  ('guns', 353),
#  ('come', 354),
#  ('science', 355),
#  ('day', 356),
#  ('atheism', 357),
#  ('co', 358),
#  ('few', 359),
#  ('anything', 360),
#  ('y', 361),
#  ('power', 362),
#  ('apple', 363),
#  ('each', 364),
#  ('little', 365),
#  ('columbia', 366),
#  ('around', 367),
#  ('50', 368),
#  ('however', 369),
#  ('john', 370),
#  ('against', 371),
#  ('bb3', 372),
#  ("didn't", 373),
#  ('again', 374),
#  ('give', 375),
#  ('darwin', 376),
#  ('tue', 377),
#  ('sport', 378),
#  ('every', 379),
#  ('best', 380),
#  ('different', 381),
#  ('public', 382),
#  ('true', 383),
#  ('02', 384),
#  ('seems', 385),
#  ('fri', 386),
#  ('key', 387),
#  ('probably', 388),
#  ('least', 389),
#  ('line', 390),
#  ('set', 391),
#  ('28', 392),
#  ('group', 393),
#  ('game', 394),
#  ('car', 395),
#  ('att', 396),
#  ('put', 397),
#  ('enough', 398),
#  ('life', 399),
#  ('research', 400),
#  ('actually', 401),
#  ('try', 402),
#  ('tell', 403),
#  ('course', 404),
#  ('support', 405),
#  ('name', 406),
#  ('real', 407),
#  ('run', 408),
#  ('great', 409),
#  ('lot', 410),
#  ('dos', 411),
#  ('1993apr20', 412),
#  ('free', 413),
#  ('40', 414),
#  ('inc', 415),
#  ('washington', 416),
#  ('list', 417),
#  ('high', 418),
#  ('04', 419),
#  ('her', 420),
#  ('post', 421),
#  ('systems', 422),
#  ('she', 423),
#  ('says', 424),
#  ('01', 425),
#  ('either', 426),
#  ('though', 427),
#  ('next', 428),
#  ('far', 429),
#  ('bill', 430),
#  ('hard', 431),
#  ('nothing', 432),
#  ('mean', 433),
#  ('03', 434),
#  ('image', 435),
#  ('called', 436),
#  ('second', 437),
#  ('old', 438),
#  ('hockey', 439),
#  ('possible', 440),
#  ('29', 441),
#  ('32', 442),
#  ('internet', 443),
#  ("you're", 444),
#  ('call', 445),
#  ('end', 446),
#  ('rather', 447),
#  ("i'd", 448),
#  ('mr', 449),
#  ('card', 450),
#  ('man', 451),
#  ('wrong', 452),
#  ('pitt', 453),
#  ('non', 454),
#  ('stanford', 455),
#  ('reason', 456),
#  ('05', 457),
#  ('thu', 458),
#  ('jesus', 459),
#  ('network', 460),
#  ('turkish', 461),
#  ('ins', 462),
#  ('athos', 463),
#  ('yes', 464),
#  ('autos', 465),
#  ('let', 466),
#  ('uwm', 467),
#  ('else', 468),
#  ('above', 469),
#  ('acs', 470),
#  ('mark', 471),
#  ('general', 472),
#  ('mon', 473),
#  ('others', 474),
#  ('baseball', 475),
#  ('gun', 476),
#  ('jewish', 477),
#  ('order', 478),
#  ('keep', 479),
#  ('based', 480),
#  ('looking', 481),
#  ('found', 482),
#  ('problems', 483),
#  ('agate', 484),
#  ('email', 485),
#  ('unix', 486),
#  ('maybe', 487),
#  ('done', 488),
#  ('technology', 489),
#  ('security', 490),
#  ('human', 491),
#  ('able', 492),
#  ('umd', 493),
#  ('files', 494),
#  ('seen', 495),
#  ('person', 496),
#  ('having', 497),
#  ('31', 498),
#  ('1993apr15', 499),
#  ('example', 500),
#  ('place', 501),
#  ('ever', 502),
#  ('bad', 503),
#  ('yet', 504),
#  ('34', 505),
#  ('info', 506),
#  ("isn't", 507),
#  ('med', 508),
#  ('1993apr21', 509),
#  ('always', 510),
#  ('american', 511),
#  ('quite', 512),
#  ('three', 513),
#  ('purdue', 514),
#  ('center', 515),
#  ('following', 516),
#  ('control', 517),
#  ('send', 518),
#  ('team', 519),
#  ('mideast', 520),
#  ('heard', 521),
#  ('thought', 522),
#  ('wrote', 523),
#  ('once', 524),
#  ('doing', 525),
#  ('33', 526),
#  ('evidence', 527),
#  ('06', 528),
#  ('electronics', 529),
#  ('means', 530),
#  ('chip', 531),
#  ('crypt', 532),
#  ('less', 533),
#  ('michael', 534),
#  ('trying', 535),
#  ('07', 536),
#  ('sgi', 537),
#  ('whether', 538),
#  ('jews', 539),
#  ('book', 540),
#  ('09', 541),
#  ('virginia', 542),
#  ('phone', 543),
#  ('000', 544),
#  ('colorado', 545),
#  ('left', 546),
#  ('opinions', 547),
#  ('start', 548),
#  ('window', 549),
#  ('away', 550),
#  ('wed', 551),
#  ('given', 552),
#  ('national', 553),
#  ('idea', 554),
#  ('several', 555),
#  ('times', 556),
#  ('children', 557),
#  ('home', 558),
#  ('rights', 559),
#  ('big', 560),
#  ('berkeley', 561),
#  ('geneva', 562),
#  ('israel', 563),
#  ('35', 564),
#  ('kind', 565),
#  ('getting', 566),
#  ('word', 567),
#  ('questions', 568),
#  ('keywords', 569),
#  ('55', 570),
#  ('41', 571),
#  ('seem', 572),
#  ('ftp', 573),
#  ('note', 574),
#  ('jpl', 575),
#  ('during', 576),
#  ('steve', 577),
#  ('45', 578),
#  ('08', 579),
#  ('remember', 580),
#  ('44', 581),
#  ('service', 582),
#  ('user', 583),
#  ('mike', 584),
#  ('games', 585),
#  ('change', 586),
#  ('standard', 587),
#  ('makes', 588),
#  ('followup', 589),
#  ('history', 590),
#  ("i'll", 591),
#  ('scsi', 592),
#  ('fi', 593),
#  ('local', 594),
#  ('38', 595),
#  ('code', 596),
#  ('saying', 597),
#  ('source', 598),
#  ('president', 599),
#  ('clipper', 600),
#  ('full', 601),
#  ('wupost', 602),
#  ('wanted', 603),
#  ('price', 604),
#  ('toronto', 605),
#  ('open', 606),
#  ('paul', 607),
#  ('today', 608),
#  ('department', 609),
#  ('perhaps', 610),
#  ('caltech', 611),
#  ('server', 612),
#  ('abortion', 613),
#  ('cannot', 614),
#  ('win', 615),
#  ('36', 616),
#  ('se', 617),
#  ('jim', 618),
#  ('already', 619),
#  ('until', 620),
#  ('ask', 621),
#  ('money', 622),
#  ('bogus', 623),
#  ('large', 624),
#  ('frank', 625),
#  ('institute', 626),
#  ('37', 627),
#  ('ucs', 628),
#  ('stuff', 629),
#  ('small', 630),
#  ('42', 631),
#  ('digex', 632),
#  ('disk', 633),
#  ('men', 634),
#  ('motorcycles', 635),
#  ('fax', 636),
#  ('1993apr16', 637),
#  ('sdd', 638),
#  ('answer', 639),
#  ('fbi', 640),
#  ('indiana', 641),
#  ('running', 642),
#  ('address', 643),
#  ('39', 644),
#  ('war', 645),
#  ('magnus', 646),
#  ('matter', 647),
#  ('speed', 648),
#  ('issue', 649),
#  ('interested', 650),
#  ('ago', 651),
#  ('buy', 652),
#  ('days', 653),
#  ('agree', 654),
#  ('original', 655),
#  ('mil', 656),
#  ('approved', 657),
#  ('bible', 658),
#  ("there's", 659),
#  ('whole', 660),
#  ('100', 661),
#  ('came', 662),
#  ('show', 663),
#  ('sale', 664),
#  ('play', 665),
#  ('works', 666),
#  ('video', 667),
#  ('pretty', 668),
#  ('told', 669),
#  ('current', 670),
#  ('type', 671),
#  ('box', 672),
#  ('1993apr19', 673),
#  ('legal', 674),
#  ('color', 675),
#  ('fire', 676),
#  ('care', 677),
#  ('hope', 678),
#  ('states', 679),
#  ('claim', 680),
#  ('48', 681),
#  ('stratus', 682),
#  ('machine', 683),
#  ('live', 684),
#  ('robert', 685),
#  ('canada', 686),
#  ('feel', 687),
#  ('love', 688),
#  ('1993apr22', 689),
#  ('armenian', 690),
#  ('understand', 691),
#  ('51', 692),
#  ('clinton', 693),
#  ('43', 694),
#  ('hand', 695),
#  ('everything', 696),
#  ('often', 697),
#  ('college', 698),
#  ('mind', 699),
#  ('house', 700),
#  ('important', 701),
#  ('math', 702),
#  ('49', 703),
#  ('everyone', 704),
#  ('simply', 705),
#  ('59', 706),
#  ('56', 707),
#  ('memory', 708),
#  ('programs', 709),
#  ('oh', 710),
#  ('g9v', 711),
#  ('netnews', 712),
#  ('april', 713),
#  ('sol', 714),
#  ('including', 715),
#  ('went', 716),
#  ('engineering', 717),
#  ('almost', 718),
#  ('earth', 719),
#  ('buffalo', 720),
#  ('church', 721),
#  ('black', 722),
#  ('truth', 723),
#  ('certainly', 724),
#  ('include', 725),
#  ('area', 726),
#  ('side', 727),
#  ("won't", 728),
#  ('46', 729),
#  ('started', 730),
#  ('54', 731),
#  ("wouldn't", 732),
#  ('display', 733),
#  ('white', 734),
#  ('guess', 735),
#  ('encryption', 736),
#  ('caen', 737),
#  ('b8f', 738),
#  ('dept', 739),
#  ('health', 740),
#  ('cornell', 741),
#  ('making', 742),
#  ('instead', 743),
#  ('pay', 744),
#  ('soviet', 745),
#  ('value', 746),
#  ('ed', 747),
#  ('comes', 748),
#  ('1993apr23', 749),
#  ('themselves', 750),
#  ('christians', 751),
#  ('bnr', 752),
#  ('later', 753),
#  ('working', 754),
#  ('although', 755),
#  ('sandvik', 756),
#  ('igor', 757),
#  ('school', 758),
#  ('check', 759),
#  ('death', 760),
#  ('ok', 761),
#  ('eff', 762),
#  ('newsreader', 763),
#  ('cb', 764),
#  ('52', 765),
#  ('vs', 766),
#  ('private', 767),
#  ('cost', 768),
#  ('st', 769),
#  ('text', 770),
#  ('anyway', 771),
#  ('single', 772),
#  ('ctr', 773),
#  ('view', 774),
#  ('faq', 775),
#  ('feed', 776),
#  ('copy', 777),
#  ('low', 778),
#  ('oz', 779),
#  ('cause', 780),
#  ('company', 781),
#  ('57', 782),
#  ('47', 783),
#  ('write', 784),
#  ('country', 785),
#  ('consider', 786),
#  ('53', 787),
#  ('unless', 788),
#  ('words', 789),
#  ('within', 790),
#  ('light', 791),
#  ('hell', 792),
#  ('difference', 793),
#  ('opinion', 794),
#  ('sat', 795),
#  ('pacific', 796),
#  ('brian', 797),
#  ('58', 798),
#  ('police', 799),
#  ('society', 800),
#  ('james', 801),
#  ('austin', 802),
#  ('armenians', 803),
#  ('a86', 804),
#  ('california', 805),
#  ('computers', 806),
#  ('san', 807),
#  ('faith', 808),
#  ('tried', 809),
#  ('known', 810),
#  ('hi', 811),
#  ('major', 812),
#  ('freenet', 813),
#  ('sort', 814),
#  ('ma', 815),
#  ('christ', 816),
#  ('clear', 817),
#  ('sense', 818),
#  ('145', 819),
#  ('wisc', 820),
#  ('deal', 821),
#  ('bitnet', 822),
#  ('ucsd', 823),
#  ('contact', 824),
#  ('political', 825),
#  ('top', 826),
#  ('ecn', 827),
#  ('cleveland', 828),
#  ('services', 829),
#  ('hedrick', 830),
#  ('religious', 831),
#  ('aramis', 832),
#  ('anybody', 833),
#  ("he's", 834),
#  ('likely', 835),
#  ('iastate', 836),
#  ('morality', 837),
#  ('talking', 838),
#  ('especially', 839),
#  ('similar', 840),
#  ('radio', 841),
#  ('city', 842),
#  ('dec', 843),
#  ('press', 844),
#  ('bob', 845),
#  ('summary', 846),
#  ('nice', 847),
#  ('package', 848),
#  ('dave', 849),
#  ('argument', 850),
#  ('uni', 851),
#  ('couple', 852),
#  ('objective', 853),
#  ('simple', 854),
#  ('happened', 855),
#  ('peter', 856),
#  ('via', 857),
#  ('blue', 858),
#  ('dead', 859),
#  ('80', 860),
#  ('certain', 861),
#  ('night', 862),
#  ('stop', 863),
#  ('force', 864),
#  ('correct', 865),
#  ('board', 866),
#  ('sound', 867),
#  ('body', 868),
#  ('exactly', 869),
#  ('per', 870),
#  ('saw', 871),
#  ('self', 872),
#  ('sex', 873),
#  ('nl', 874),
#  ('asked', 875),
#  ('privacy', 876),
#  ('level', 877),
#  ('tin', 878),
#  ('third', 879),
#  ('emory', 880),
#  ('books', 881),
#  ('took', 882),
#  ('mot', 883),
#  ('killed', 884),
#  ('thus', 885),
#  ('size', 886),
#  ('screen', 887),
#  ('east', 888),
#  ('na', 889),
#  ('moral', 890),
#  ('fine', 891),
#  ('york', 892),
#  ('israeli', 893),
#  ('theory', 894),
#  ('provide', 895),
#  ('ap', 896),
#  ('among', 897),
#  ('sorry', 898),
#  ('fast', 899),
#  ('situation', 900),
#  ('common', 901),
#  ('head', 902),
#  ('monitor', 903),
#  ('format', 904),
#  ('form', 905),
#  ('taken', 906),
#  ('whatever', 907),
#  ('business', 908),
#  ('position', 909),
#  ('myself', 910),
#  ('groups', 911),
#  ('test', 912),
#  ('reading', 913),
#  ('sni', 914),
#  ('statement', 915),
#  ('become', 916),
#  ("they're", 917),
#  ('images', 918),
#  ('goes', 919),
#  ('fan', 920),
#  ('answers', 921),
#  ('western', 922),
#  ('written', 923),
#  ('pub', 924),
#  ('scott', 925),
#  ('early', 926),
#  ('usually', 927),
#  ('upon', 928),
#  ('motif', 929),
#  ('discussion', 930),
#  ('mchp', 931),
#  ('red', 932),
#  ('women', 933),
#  ('itself', 934),
#  ('personal', 935),
#  ('experience', 936),
#  ('guy', 937),
#  ('peace', 938),
#  ('except', 939),
#  ('disclaimer', 940),
#  ('elroy', 941),
#  ('rest', 942),
#  ('du', 943),
#  ('driver', 944),
#  ('application', 945),
#  ('peachnet', 946),
#  ('interesting', 947),
#  ('umn', 948),
#  ('swrinde', 949),
#  ('output', 950),
#  ('mine', 951),
#  ('laws', 952),
#  ('manager', 953),
#  ('cup', 954),
#  ('four', 955),
#  ('bike', 956),
#  ('players', 957),
#  ("we're", 958),
#  ('past', 959),
#  ("haven't", 960),
#  ('hear', 961),
#  ('nor', 962),
#  ('division', 963),
#  ('transfer', 964),
#  ('pl', 965),
#  ('bus', 966),
#  ('particular', 967),
#  ('account', 968),
#  ('keys', 969),
#  ('add', 970),
#  ('easy', 971),
#  ('corp', 972),
#  ('period', 973),
#  ('advance', 974),
#  ('turn', 975),
#  ('therefore', 976),
#  ('arizona', 977),
#  ('ksu', 978),
#  ('study', 979),
#  ('needed', 980),
#  ('physics', 981),
#  ('tu', 982),
#  ('according', 983),
#  ('special', 984),
#  ('posted', 985),
#  ('ii', 986),
#  ('mu', 987),
#  ('ames', 988),
#  ('users', 989),
#  ('al', 990),
#  ('needs', 991),
#  ('happen', 992),
#  ('astro', 993),
#  ('isc', 994),
#  ('office', 995),
#  ('short', 996),
#  ('model', 997),
#  ('microsoft', 998),
#  ('hit', 999),
#  ('numbers', 1000),
#  ...]

# %%
data[0].shape
# Out:
# (1000,)

# %%
import pandas as pd

# %%
df = pd.read_csv('reviews_with_language.csv')
# Out:
# /home/i008/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lab
# Out:
# array(['unknown'], dtype=object)
